# %%
# Installations
# !pip install torch torchvision matplotlib opencv-python ultralytics
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Importation des bibliothèques
import torch
from PIL import Image
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
# Chargement de Yolo
model = YOLO("yolo11n.pt")
#yolov8n
#yolo11x.pt ATTENTION 109Mo

# %%
#Load une image
# Vous devez rentrer le chemin de l'image a analyser
# Une image par défaut est mise mais cela m'étonnerais que vous l'ayez 
def load_image(path):
    img = Image.open(path)
    return img

# Interface
image_path = input("Entrez le chemin de l'image à analyser (ou laissez vide pour utiliser l'image par défaut) : ")
if not image_path:
    image_path = "Unknown.jpg"  

img = load_image(image_path)
# Out:
# Entrez le chemin de l'image à analyser (ou laissez vide pour utiliser l'image par défaut) :  81cdd8386afabed5c1b09f24d94dba05758a08d5.jpg

# %%
# Prédiction
results = model(image_path)
# Out:
# image 1/1 /Users/ewanquelo/Downloads/81cdd8386afabed5c1b09f24d94dba05758a08d5.jpg: 352x640 4 cows, 252.3ms
# Speed: 2.6ms preprocess, 252.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)

# %%
# Affichage du résultat de l'analyse
plt.figure(figsize=(10, 10))
plt.imshow(results[0].plot())
plt.axis("off")
plt.title("Résultats de la prédiction")
plt.show()
